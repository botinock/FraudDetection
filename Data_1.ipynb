# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Data_1 (+).xlsx")
df
# Out:
#       conversion_datetime                      conversion_unique_id  \
# 0     2019-01-04 01:06:23  001c675c7cdb23b2cf9d6316aebba2ab0222339b
# 1     2019-01-03 12:19:43  007c9a5411442400766cd0f5d0807da5ccfe06d1
# 2     2019-01-03 05:36:11  019b86102e6aad24386922e6d5227c215f688c43
# 3     2019-01-06 13:47:34  019e123a977fbf9676e9598c1534eda98fc1db5d
# 4     2019-01-03 21:34:42  01cd0016a3719bd60d0c6542e98aafd458a8430f
# ...                   ...                                       ...
# 1054  2019-01-04 18:40:50  fea70ac3e8ccb87206c6e2c580200bf2af82d5bd
# 1055  2019-01-05 12:23:04  ff1312a2949d4dd7110e5730dd2513470d89ae24
# 1056  2019-01-03 13:54:03  ff35f6db6226b4b5f3f62c916a1151f63c4cd155
# 1057  2019-01-05 20:21:16  ff8ab18831158b3842292dd46f0d5578927429ab
# 1058  2019-01-04 21:16:19  ffb3870cafc7514d05a74dd276ef4f18c163afa6
#
#      attributed_touch_time offer_id publisher_id
# 0      2019-01-03 21:56:15      APP    Publisher
# 1      2019-01-03 11:10:33      APP    Publisher
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 5 columns):
# conversion_datetime      1059 non-null object
# conversion_unique_id     1059 non-null object
# attributed_touch_time    1059 non-null object
# offer_id                 1059 non-null object
# publisher_id             1059 non-null object
# dtypes: object(5)
# memory usage: 41.5+ KB

# %%
df.dtypes
# Out:
# conversion_datetime      object
# conversion_unique_id     object
# attributed_touch_time    object
# offer_id                 object
# publisher_id             object
# dtype: object

# %%
df["tti"] = (pd.to_datetime(df["conversion_datetime"]) - pd.to_datetime(df["attributed_touch_time"])).astype('timedelta64[s]')

# %%
df
# Out:
#       conversion_datetime                      conversion_unique_id  \
# 0     2019-01-04 01:06:23  001c675c7cdb23b2cf9d6316aebba2ab0222339b
# 1     2019-01-03 12:19:43  007c9a5411442400766cd0f5d0807da5ccfe06d1
# 2     2019-01-03 05:36:11  019b86102e6aad24386922e6d5227c215f688c43
# 3     2019-01-06 13:47:34  019e123a977fbf9676e9598c1534eda98fc1db5d
# 4     2019-01-03 21:34:42  01cd0016a3719bd60d0c6542e98aafd458a8430f
# ...                   ...                                       ...
# 1054  2019-01-04 18:40:50  fea70ac3e8ccb87206c6e2c580200bf2af82d5bd
# 1055  2019-01-05 12:23:04  ff1312a2949d4dd7110e5730dd2513470d89ae24
# 1056  2019-01-03 13:54:03  ff35f6db6226b4b5f3f62c916a1151f63c4cd155
# 1057  2019-01-05 20:21:16  ff8ab18831158b3842292dd46f0d5578927429ab
# 1058  2019-01-04 21:16:19  ffb3870cafc7514d05a74dd276ef4f18c163afa6
#
#      attributed_touch_time offer_id publisher_id      tti
# 0      2019-01-03 21:56:15      APP    Publisher  11408.0
# ...

# %%
df.describe()
# Out:
#                  tti
# count    1059.000000
# mean    21651.459868
# std     69051.614924
# min         2.000000
# 25%      1726.500000
# 50%      7801.000000
# 75%     15896.000000
# max    585535.000000

# %%
ax = df['tti'].plot.kde()
ax.set_title('Delta sec')
ax.set_xscale('log')
ax.set_xlim(left=1)
ax.plot()
# Out:
# []

# %%
df.to_excel("Data_1_out.xlsx")
